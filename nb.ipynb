# %%
import diffolars.diff as dd
from diffolars.demo import get_df_pair

# %%
dfs = get_df_pair(10, 10, n_new_cols=5, n_new_rows=5)
o = dfs['original']
m = dfs['mutated']
# Out:
# Generating initial dataset with 10 rows and 10 columns.
# Generated mutated dataset.

# %%
dd.column_intercept(o, m)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 dd.column_intercept([1, 2, 3], m)
#       2
#       3
#
# File ~\Documents\CSE550\GitLab\diffolars\src\diffolars\diff.py:40, in column_intercept(acol, bcol, acol_suffix, bcol_suffix, record_id_col)
#      38 acol = get_cols(acol)
#      39 bcol = get_cols(bcol)
# ---> 40 o = {c.replace(acol_suffix, '') for c in acol}
#      41 m = {c.replace(bcol_suffix, '') for c in bcol}
#      42 i = o.intersection(m)
#
# AttributeError: 'int' object has no attribute 'replace'
